# %% [markdown]
# ![thumb-1920-1108877.jpg](attachment:6035f532-d8d1-4ba4-ad8d-7fa60a03f0d9.jpg)

# %%
import shutil
import os 
import random

# %%
source= 'universe/'

# %%
destination='backup/'

# %%
source_files= os.listdir(source)

# %%
source_files
# Out:
# ['cover001.png',
#  'cover002.png',
#  'cover003.png',
#  'cover004.png',
#  'cover005.png',
#  'cover006.png',
#  'cover007.png',
#  'cover008.png',
#  'cover009.png',
#  'cover010.png',
#  'cover011.png',
#  'cover012.png',
#  'cover013.png',
#  'cover014.png',
#  'cover015.png',
#  'cover016.png',
#  'cover017.png',
#  'cover018.png',
#  'cover019.png',
#  'cover020.png',
#  'cover021.png',
#  'cover022.png',
#  'cover023.png',
#  'cover024.png',
#  'cover025.png',
#  'cover026.png',
#  'cover027.png',
#  'cover028.png',
#  'cover029.png',
#  'cover030.png',
#  'cover031.png',
#  'cover032.png',
#  'cover033.png',
#  'cover034.png',
#  'cover035.png',
#  'cover036.png',
#  'cover037.png',
#  'cover038.png',
#  'cover039.png',
#  'cover040.png',
#  'cover041.png',
#  'cover042.png',
#  'cover043.png',
#  'cover044.png',
#  'cover045.png',
#  'cover046.png',
#  'cover047.png',
#  'cover048.png',
#  'cover049.png',
#  'cover050.png']

# %%
for file in source_files :
    f= os.path.join(source ,file)
    if os.path.isfile(f):
        shutil.copy(f , destination)
print(os.listdir(destination))
print('_'*50)
print(len(os.listdir(destination)))
# Out:
# ['cover001.png', 'cover002.png', 'cover003.png', 'cover004.png', 'cover005.png', 'cover006.png', 'cover007.png', 'cover008.png', 'cover009.png', 'cover010.png', 'cover011.png', 'cover012.png', 'cover013.png', 'cover014.png', 'cover015.png', 'cover016.png', 'cover017.png', 'cover018.png', 'cover019.png', 'cover020.png', 'cover021.png', 'cover022.png', 'cover023.png', 'cover024.png', 'cover025.png', 'cover026.png', 'cover027.png', 'cover028.png', 'cover029.png', 'cover030.png', 'cover031.png', 'cover032.png', 'cover033.png', 'cover034.png', 'cover035.png', 'cover036.png', 'cover037.png', 'cover038.png', 'cover039.png', 'cover040.png', 'cover041.png', 'cover042.png', 'cover043.png', 'cover044.png', 'cover045.png', 'cover046.png', 'cover047.png', 'cover048.png', 'cover049.png', 'cover050.png']
# __________________________________________________
# 50

# %%
source
# Out:
# 'universe/'

# %%
def Thanos_victims(list_of_universe):
    half = int(len(list_of_universe)/2)
    try:
  
        for i in range(25) :
            source='universe/'
            list_of_universe= os.listdir(source)
        
        
            
            os.remove( source+ random.choice(list_of_universe))
            
        print('Thanos destroyed half the universe ')
        print(int(len(list_of_universe)-1))

    except  IndexError:
            print(f'Thanos destroyed half and the universe became empty.\nUniverse = {int(len(list_of_universe))}')

# %%
Thanos_victims(source_files)
# Out:
# Thanos destroyed half the universe
# 25

# %%
source_files= os.listdir(source)

# %%
source_files
# Out:
# ['cover001.png',
#  'cover002.png',
#  'cover004.png',
#  'cover006.png',
#  'cover008.png',
#  'cover009.png',
#  'cover010.png',
#  'cover011.png',
#  'cover014.png',
#  'cover018.png',
#  'cover019.png',
#  'cover020.png',
#  'cover021.png',
#  'cover025.png',
#  'cover026.png',
#  'cover036.png',
#  'cover037.png',
#  'cover039.png',
#  'cover040.png',
#  'cover042.png',
#  'cover043.png',
#  'cover044.png',
#  'cover045.png',
#  'cover049.png',
#  'cover050.png']

# %%
len(source_files)
# Out:
# 25

# %%
destination_files=os.listdir(destination)
destination_files
# Out:
# ['cover001.png',
#  'cover002.png',
#  'cover003.png',
#  'cover004.png',
#  'cover005.png',
#  'cover006.png',
#  'cover007.png',
#  'cover008.png',
#  'cover009.png',
#  'cover010.png',
#  'cover011.png',
#  'cover012.png',
#  'cover013.png',
#  'cover014.png',
#  'cover015.png',
#  'cover016.png',
#  'cover017.png',
#  'cover018.png',
#  'cover019.png',
#  'cover020.png',
#  'cover021.png',
#  'cover022.png',
#  'cover023.png',
#  'cover024.png',
#  'cover025.png',
#  'cover026.png',
#  'cover027.png',
#  'cover028.png',
#  'cover029.png',
#  'cover030.png',
#  'cover031.png',
#  'cover032.png',
#  'cover033.png',
#  'cover034.png',
#  'cover035.png',
#  'cover036.png',
#  'cover037.png',
#  'cover038.png',
#  'cover039.png',
#  'cover040.png',
#  'cover041.png',
#  'cover042.png',
#  'cover043.png',
#  'cover044.png',
#  'cover045.png',
#  'cover046.png',
#  'cover047.png',
#  'cover048.png',
#  'cover049.png',
#  'cover050.png']

# %%
for file in destination_files :
    f= os.path.join(destination ,file)
    if os.path.isfile(f):
        shutil.copy(f , source)
print(os.listdir(source))
print('_'*50)
print(len(os.listdir(source)))
# Out:
# ['cover001.png', 'cover002.png', 'cover003.png', 'cover004.png', 'cover005.png', 'cover006.png', 'cover007.png', 'cover008.png', 'cover009.png', 'cover010.png', 'cover011.png', 'cover012.png', 'cover013.png', 'cover014.png', 'cover015.png', 'cover016.png', 'cover017.png', 'cover018.png', 'cover019.png', 'cover020.png', 'cover021.png', 'cover022.png', 'cover023.png', 'cover024.png', 'cover025.png', 'cover026.png', 'cover027.png', 'cover028.png', 'cover029.png', 'cover030.png', 'cover031.png', 'cover032.png', 'cover033.png', 'cover034.png', 'cover035.png', 'cover036.png', 'cover037.png', 'cover038.png', 'cover039.png', 'cover040.png', 'cover041.png', 'cover042.png', 'cover043.png', 'cover044.png', 'cover045.png', 'cover046.png', 'cover047.png', 'cover048.png', 'cover049.png', 'cover050.png']
# __________________________________________________
# 50

# %%
source_files= os.listdir(source)
source_files
# Out:
# ['cover001.png',
#  'cover002.png',
#  'cover003.png',
#  'cover004.png',
#  'cover005.png',
#  'cover006.png',
#  'cover007.png',
#  'cover008.png',
#  'cover009.png',
#  'cover010.png',
#  'cover011.png',
#  'cover012.png',
#  'cover013.png',
#  'cover014.png',
#  'cover015.png',
#  'cover016.png',
#  'cover017.png',
#  'cover018.png',
#  'cover019.png',
#  'cover020.png',
#  'cover021.png',
#  'cover022.png',
#  'cover023.png',
#  'cover024.png',
#  'cover025.png',
#  'cover026.png',
#  'cover027.png',
#  'cover028.png',
#  'cover029.png',
#  'cover030.png',
#  'cover031.png',
#  'cover032.png',
#  'cover033.png',
#  'cover034.png',
#  'cover035.png',
#  'cover036.png',
#  'cover037.png',
#  'cover038.png',
#  'cover039.png',
#  'cover040.png',
#  'cover041.png',
#  'cover042.png',
#  'cover043.png',
#  'cover044.png',
#  'cover045.png',
#  'cover046.png',
#  'cover047.png',
#  'cover048.png',
#  'cover049.png',
#  'cover050.png']

# %%
len(source_files)
# Out:
# 50

# %%
os.getcwd()
# Out:
# 'E:\\Z e z o\\Session\\My project\\Thanos Project'

# %%
os.mkdir('New_Univers')

# %%
os.listdir('.')
# Out:
# ['.ipynb_checkpoints',
#  'backup',
#  'New_Univers',
#  'Read me.txt',
#  'Thanos (Abdelaziz Anan).ipynb',
#  'Thanos Project.rar',
#  'thumb-1920-1108877.jpg',
#  'universe']

# %%
New_Univers = 'New_Univers/'

# %%
for file in source_files :
   
    
        
    f= os.path.join(source ,random.choice(source_files))
      
        
    if os.path.isfile(f):
            
        shutil.copy(f , New_Univers)

print(os.listdir(New_Univers))
        
print('_'*50)
print(len(os.listdir(New_Univers)))
# Out:
# ['cover002.png', 'cover003.png', 'cover004.png', 'cover005.png', 'cover007.png', 'cover008.png', 'cover009.png', 'cover012.png', 'cover014.png', 'cover019.png', 'cover020.png', 'cover021.png', 'cover022.png', 'cover023.png', 'cover024.png', 'cover026.png', 'cover027.png', 'cover029.png', 'cover030.png', 'cover031.png', 'cover033.png', 'cover034.png', 'cover036.png', 'cover037.png', 'cover039.png', 'cover041.png', 'cover042.png', 'cover043.png', 'cover044.png', 'cover045.png', 'cover047.png', 'cover048.png', 'cover049.png']
# __________________________________________________
# 33

# %%
New_Univers_files= os.listdir(New_Univers)
New_Univers_files
# Out:
# ['cover002.png',
#  'cover003.png',
#  'cover004.png',
#  'cover005.png',
#  'cover007.png',
#  'cover008.png',
#  'cover009.png',
#  'cover012.png',
#  'cover014.png',
#  'cover019.png',
#  'cover020.png',
#  'cover021.png',
#  'cover022.png',
#  'cover023.png',
#  'cover024.png',
#  'cover026.png',
#  'cover027.png',
#  'cover029.png',
#  'cover030.png',
#  'cover031.png',
#  'cover033.png',
#  'cover034.png',
#  'cover036.png',
#  'cover037.png',
#  'cover039.png',
#  'cover041.png',
#  'cover042.png',
#  'cover043.png',
#  'cover044.png',
#  'cover045.png',
#  'cover047.png',
#  'cover048.png',
#  'cover049.png']

# %%
len(New_Univers_files)
# Out:
# 33
